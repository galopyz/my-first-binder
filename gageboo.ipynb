# %% [markdown]
# # Monthly ga ge boo

# %% [markdown]
# Home expenses:
# - HOA: 160
# - home insurance: 70
# - property tax: 200

# %%
expense = {'home': 160 + 70 + 200}
expense
# Out:
# {'home': 430}

# %% [markdown]
# Utility fees
# - electric: 100
# - water: 100
# - internet: 80
# - phone: 30

# %%
expense['utility'] = 100 + 100
expense['internet'] = 80
expense['phone'] = 30
expense
# Out:
# {'home': 430, 'utility': 200, 'internet': 80, 'phone': 30}

# %% [markdown]
# Car expenses:
# - insuarnce: 70
# - gas: 30

# %%
expense['car'] = 100
expense
# Out:
# {'home': 430, 'utility': 200, 'internet': 80, 'phone': 30, 'car': 100}

# %%
def total():
    return sum(expense.values())

# %%
total()
# Out:
# 840

# %% [markdown]
# So far, it is $840.

# %% [markdown]
# Grocery may take about $150 a week, which makes $600 a month.

# %%
expense['grocery'] = 600
expense
# Out:
# {'home': 430,
#  'utility': 200,
#  'internet': 80,
#  'phone': 30,
#  'car': 100,
#  'grocery': 600}

# %%
total()
# Out:
# 1440
